# %% [markdown]
# ### Dixon Coles Model
# https://penaltyblog.readthedocs.io/en/latest/ratings/massey_ratings.html
#
# https://www.pro-football-reference.com/years/2022/games.htm

# %%
# %pip install penaltyblog
# Out:
# Requirement already satisfied: penaltyblog in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (0.5.0)
# Requirement already satisfied: selenium<5.0.0,>=4.3.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (4.5.0)
# Requirement already satisfied: cssselect<2.0.0,>=1.1.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (1.1.0)
# Requirement already satisfied: webdriver-manager<4.0.0,>=3.8.3 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (3.8.4)
# Requirement already satisfied: scipy<2.0.0,>=1.7.3 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (1.9.3)
# Requirement already satisfied: PuLP<3.0.0,>=2.6.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (2.6.0)
# Requirement already satisfied: pandas<2.0.0,>=1.3.1 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (1.4.4)
# Requirement already satisfied: numpy<2.0.0,>=1.21.1 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (1.23.3)
# Requirement already satisfied: pymc<5.0.0,>=4.1.4 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (4.2.2)
# Requirement already satisfied: lxml<5.0.0,>=4.9.1 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from penaltyblog) (4.9.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pandas<2.0.0,>=1.3.1->penaltyblog) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pandas<2.0.0,>=1.3.1->penaltyblog) (2.8.2)
# Requirement already satisfied: cloudpickle in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pymc<5.0.0,>=4.1.4->penaltyblog) (2.2.0)
# Requirement already satisfied: arviz>=0.12.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pymc<5.0.0,>=4.1.4->penaltyblog) (0.13.0)
# Requirement already satisfied: fastprogress>=0.2.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pymc<5.0.0,>=4.1.4->penaltyblog) (1.0.3)
# Requirement already satisfied: aeppl==0.0.38 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pymc<5.0.0,>=4.1.4->penaltyblog) (0.0.38)
# Requirement already satisfied: aesara==2.8.7 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pymc<5.0.0,>=4.1.4->penaltyblog) (2.8.7)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pymc<5.0.0,>=4.1.4->penaltyblog) (4.4.0)
# Requirement already satisfied: cachetools>=4.2.1 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from pymc<5.0.0,>=4.1.4->penaltyblog) (5.2.0)
# Requirement already satisfied: miniKanren in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from aesara==2.8.7->pymc<5.0.0,>=4.1.4->penaltyblog) (1.0.3)
# Requirement already satisfied: cons in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from aesara==2.8.7->pymc<5.0.0,>=4.1.4->penaltyblog) (0.4.5)
# Requirement already satisfied: logical-unification in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from aesara==2.8.7->pymc<5.0.0,>=4.1.4->penaltyblog) (0.4.5)
# Requirement already satisfied: filelock in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from aesara==2.8.7->pymc<5.0.0,>=4.1.4->penaltyblog) (3.8.0)
# Requirement already satisfied: etuples in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from aesara==2.8.7->pymc<5.0.0,>=4.1.4->penaltyblog) (0.3.8)
# Requirement already satisfied: setuptools>=48.0.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from aesara==2.8.7->pymc<5.0.0,>=4.1.4->penaltyblog) (63.4.1)
# Requirement already satisfied: trio~=0.17 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from selenium<5.0.0,>=4.3.0->penaltyblog) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from selenium<5.0.0,>=4.3.0->penaltyblog) (1.26.12)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from selenium<5.0.0,>=4.3.0->penaltyblog) (2022.9.24)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from selenium<5.0.0,>=4.3.0->penaltyblog) (0.9.2)
# Requirement already satisfied: python-dotenv in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from webdriver-manager<4.0.0,>=3.8.3->penaltyblog) (0.21.0)
# Requirement already satisfied: tqdm in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from webdriver-manager<4.0.0,>=3.8.3->penaltyblog) (4.64.1)
# Requirement already satisfied: requests in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from webdriver-manager<4.0.0,>=3.8.3->penaltyblog) (2.28.1)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (3.5.2)
# Requirement already satisfied: xarray-einstats>=0.3 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (0.3.0)
# Requirement already satisfied: xarray>=0.21.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (2022.10.0)
# Requirement already satisfied: netcdf4 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (1.6.1)
# Requirement already satisfied: packaging in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.1->penaltyblog) (1.16.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (22.1.0)
# Requirement already satisfied: sniffio in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (1.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (1.0.0rc9)
# Requirement already satisfied: outcome in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (1.2.0)
# Requirement already satisfied: idna in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (3.4)
# Requirement already satisfied: wsproto>=0.14 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from trio-websocket~=0.9->selenium<5.0.0,>=4.3.0->penaltyblog) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from urllib3[socks]~=1.26->selenium<5.0.0,>=4.3.0->penaltyblog) (1.7.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from requests->webdriver-manager<4.0.0,>=3.8.3->penaltyblog) (2.1.1)
# Requirement already satisfied: colorama in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from tqdm->webdriver-manager<4.0.0,>=3.8.3->penaltyblog) (0.4.5)
# Requirement already satisfied: pycparser in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium<5.0.0,>=4.3.0->penaltyblog) (2.21)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from matplotlib>=3.5->arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from matplotlib>=3.5->arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from matplotlib>=3.5->arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from matplotlib>=3.5->arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from matplotlib>=3.5->arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (1.4.2)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5.0.0,>=4.3.0->penaltyblog) (0.14.0)
# Requirement already satisfied: toolz in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from logical-unification->aesara==2.8.7->pymc<5.0.0,>=4.1.4->penaltyblog) (0.12.0)
# Requirement already satisfied: multipledispatch in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from logical-unification->aesara==2.8.7->pymc<5.0.0,>=4.1.4->penaltyblog) (0.6.0)
# Requirement already satisfied: cftime in c:\users\samue\anaconda3\envs\apuestas\lib\site-packages (from netcdf4->arviz>=0.12.0->pymc<5.0.0,>=4.1.4->penaltyblog) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import penaltyblog as pb
# Out:
# WARNING (aesara.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (aesara.configdefaults): g++ not detected!  Aesara will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set Aesara flags cxx to an empty string.
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
import nfl_data_py as nfl

# %%
try:
    import nfl_data_py as nfl
except:
    ! pip install nfl_data_py

# %%
semana = 8
temporada = 2022
normalizacion = 1
MAX = 10
df = nfl.import_schedules([temporada])
df = df[df['week']<semana]

# %%
df = df.rename(columns={'away_team':'AwayTeam',
                                   'home_team':'HomeTeam',
                       'away_score':'FTHG',
                       'home_score':'FTAG'})

# %%
df[['FTHG','FTAG']]
# Out:
#       FTHG  FTAG
# 6137  31.0  10.0
# 6138  27.0  26.0
# 6139  26.0  24.0
# 6140  10.0  19.0
# 6141  23.0  20.0
# ...    ...   ...
# 6240  20.0  38.0
# 6241  37.0  23.0
# 6242  44.0  23.0
# 6243  10.0  16.0
# 6244  33.0  14.0
#
# [108 rows x 2 columns]

# %%
df[df['AwayTeam']=='BUF']
# Out:
#               game_id  season game_type  week     gameday   weekday gametime  \
# 6137   2022_01_BUF_LA    2022       REG     1  2022-09-08  Thursday    20:20
# 6173  2022_03_BUF_MIA    2022       REG     3  2022-09-25    Sunday    13:00
# 6188  2022_04_BUF_BAL    2022       REG     4  2022-10-02    Sunday    13:00
# 6228   2022_06_BUF_KC    2022       REG     6  2022-10-16    Sunday    16:25
#
#      AwayTeam  FTHG HomeTeam  ...  wind  away_qb_id  home_qb_id  away_qb_name  \
# 6137      BUF  31.0       LA  ...   NaN  00-0034857  00-0026498    Josh Allen
# 6173      BUF  19.0      MIA  ...   NaN  00-0034857  00-0036212    Josh Allen
# 6188      BUF  23.0      BAL  ...   NaN  00-0034857  00-0034796    Josh Allen
# 6228      BUF  24.0       KC  ...   NaN  00-0034857  00-0033873    Josh Allen
#
#           home_qb_name      away_coach     home_coach        referee  \
# 6137  Matthew Stafford  Sean McDermott     Sean McVay  Carl Cheffers
# 6173    Tua Tagovailoa  Sean McDermott  Mike McDaniel      Alex Kemp
# 6188     Lamar Jackson  Sean McDermott  John Harbaugh   Jerome Boger
# 6228   Patrick Mahomes  Sean McDermott      Andy Reid     Brad Allen
#
#      stadium_id                          stadium
# 6137      LAX01                     SoFi Stadium
# 6173      MIA00                Hard Rock Stadium
# 6188      BAL00                 M&T Bank Stadium
# 6228      KAN00  GEHA Field at Arrowhead Stadium
#
# [4 rows x 45 columns]

# %%
if normalizacion == 1:
    df['FTHG'] = (df['FTHG'] - df['FTHG'].min()) / ( df['FTHG'].max() - df['FTHG'].min()) * MAX
    df['FTAG'] = (df['FTAG'] - df['FTAG'].min()) / ( df['FTAG'].max() - df['FTAG'].min()) * MAX

# %%
df[["FTHG", "FTAG"]].mean()
# Out:
# FTHG    4.390432
# FTAG    4.603175
# dtype: float64

# %%
df[['FTHG','FTAG']]
# Out:
#           FTHG      FTAG
# 6137  6.458333  1.666667
# 6138  5.625000  5.476190
# 6139  5.416667  5.000000
# 6140  2.083333  3.809524
# 6141  4.791667  4.047619
# ...        ...       ...
# 6240  4.166667  8.333333
# 6241  7.708333  4.761905
# 6242  9.166667  4.761905
# 6243  2.083333  3.095238
# 6244  6.875000  2.619048
#
# [108 rows x 2 columns]

# %%
pr = nfl.import_schedules([temporada])
pr = pr[pr['week']==semana ]
juegos = pr['week'].count()

# %%
results_past = nfl.import_schedules([temporada])
results_past = results_past[results_past['week']==(semana-1)]
results_past[['away_team','home_team','away_score','home_score']]
results_past = results_past['Away Winner'] = results_past['away_score'] > results_past['home_score']
results_past
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\samue\Documents\Apuestas\DixonColes.ipynb Celda 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/samue/Documents/Apuestas/DixonColes.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> results_past = nfl.import_schedules([temporada])
#       <a href='vscode-notebook-cell:/c%3A/Users/samue/Documents/Apuestas/DixonColes.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> results_past = results_past[results_past['week']==(semana-1)]
#       <a href='vscode-notebook-cell:/c%3A/Users/samue/Documents/Apuestas/DixonColes.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> results_past[['away_team','home_team','away_score','home_score']]
#
# NameError: name 'nfl' is not defined

# %%
pr = pr.rename(columns={'away_team':'AwayTeam',
                                   'home_team':'HomeTeam',
                       'away_score':'FTHG',
                       'home_score':'FTAG'})

# %%
model = pb.models.DixonColesGoalModel(df["FTHG"], df["FTAG"], df["HomeTeam"], df["AwayTeam"])
model.fit()

# %%
print('Dixon Coles Model')
print(f'Season: {temporada}')
print(f'Week: {semana}')
for i in range(0,juegos):
    EL = pr.iloc[i]['HomeTeam']
    EV = pr.iloc[i]['AwayTeam']
    probs = model.predict(EL, EV)
    if probs.home_win >= .50 :
        print(f'L {EL} -{100/probs.home_win:.0f} vs V {EV} {100/probs.away_win:.0f}')
    elif probs.away_win >= .50:
        print(f'L {EL} {100/probs.home_win:.0f} vs V {EV} -{100/probs.away_win:.0f}')
    else:
        print(f'L {EL} {100/probs.home_win:.0f} vs V {EV} {100/probs.away_win:.0f}')
# Out:
# Dixon Coles Model
# Season: 2022
# Week: 8
# L TB -156 vs V BAL 449
# L JAX 393 vs V DEN -176
# L ATL 271 vs V CAR 207
# L DAL 599 vs V CHI -145
# L DET -159 vs V MIA 385
# L MIN 310 vs V ARI -190
# L NO -183 vs V LV 296
# L NYJ 290 vs V NE -200
# L PHI 1018 vs V PIT -122
# L HOU -159 vs V TEN 408
# L IND 261 vs V WAS 226
# L LA -183 vs V SF 334
# L SEA -154 vs V NYG 429
# L BUF 2591 vs V GB -110
# L CLE -141 vs V CIN 538

# %%
model
# Out:
# Module: Penaltyblog
#
# Model: Dixon and Coles
#
# Number of parameters: 66
# Log Likelihood: -358.726
# AIC: 849.452
#
# Team                 Attack               Defence
# ------------------------------------------------------------
# ARI                  1.045                0.08
# ATL                  1.08                 0.412
# BAL                  0.998                0.868
# BUF                  0.269                0.619
# CAR                  1.182                0.082
# CHI                  1.131                -0.009
# CIN                  0.723                0.421
# CLE                  1.338                0.517
# DAL                  0.73                 0.349
# DEN                  0.75                 -0.175
# DET                  1.555                0.831
# GB                   1.094                0.256
# HOU                  1.107                0.162
# IND                  0.948                0.129
# JAX                  1.001                0.442
# KC                   1.295                0.822
# LA                   1.07                 0.234
# LAC                  1.129                0.353
# LV                   1.293                0.424
# MIA                  1.107                0.687
# MIN                  0.83                 0.276
# NE                   0.606                0.277
# NO                   1.308                0.473
# NYG                  0.883                0.317
# NYJ                  0.861                0.417
# PHI                  0.786                0.617
# PIT                  1.161                0.246
# SEA                  1.313                0.397
# SF                   0.594                0.242
# TB                   0.652                0.171
# TEN                  1.206                0.415
# WAS                  0.954                -0.009
# ------------------------------------------------------------
# Home Advantage: 0.0
# Rho: -0.1

# %%
model.get_params()
# Out:
# {'attack_ARI': 1.045250685924421,
#  'attack_ATL': 1.0795271096270491,
#  'attack_BAL': 0.9984700722881319,
#  'attack_BUF': 0.26872834647900695,
#  'attack_CAR': 1.1823357460495256,
#  'attack_CHI': 1.1308404764612792,
#  'attack_CIN': 0.7231398547912425,
#  'attack_CLE': 1.3377696285722929,
#  'attack_DAL': 0.730205991606194,
#  'attack_DEN': 0.7503922586351598,
#  'attack_DET': 1.5550676462984276,
#  'attack_GB': 1.0935051310138282,
#  'attack_HOU': 1.1074136039373967,
#  'attack_IND': 0.9478082142846533,
#  'attack_JAX': 1.0007855364862817,
#  'attack_KC': 1.2949421294991976,
#  'attack_LA': 1.0703229489397794,
#  'attack_LAC': 1.1293130862352134,
#  'attack_LV': 1.2932073199117757,
#  'attack_MIA': 1.1068288939794542,
#  'attack_MIN': 0.8304194741498415,
#  'attack_NE': 0.6057112597255495,
#  'attack_NO': 1.3080770226191942,
#  'attack_NYG': 0.8830474538534983,
#  'attack_NYJ': 0.8614460823787152,
#  'attack_PHI': 0.7857007474206107,
#  'attack_PIT': 1.1610037758484284,
#  'attack_SEA': 1.3131365913174198,
#  'attack_SF': 0.5939112255461432,
#  'attack_TB': 0.651937709676376,
#  'attack_TEN': 1.2055138764422504,
#  'attack_WAS': 0.9542401000016587,
#  'defence_ARI': 0.07999438362921223,
#  'defence_ATL': 0.4124915830472987,
#  'defence_BAL': 0.8681667826238548,
#  'defence_BUF': 0.6194951910388866,
#  'defence_CAR': 0.08229060137593781,
#  'defence_CHI': -0.008733491183150378,
#  'defence_CIN': 0.4205853757686589,
#  'defence_CLE': 0.5173357271323994,
#  'defence_DAL': 0.34918930952080995,
#  'defence_DEN': -0.1752534377820742,
#  'defence_DET': 0.8307943402851601,
#  'defence_GB': 0.2563877359098372,
#  'defence_HOU': 0.16176683774979242,
#  'defence_IND': 0.12924808554341585,
#  'defence_JAX': 0.4418860028397451,
#  'defence_KC': 0.8216448160297306,
#  'defence_LA': 0.23400847215058046,
#  'defence_LAC': 0.35294907887630905,
#  'defence_LV': 0.42448791519937296,
#  'defence_MIA': 0.6870230022960618,
#  'defence_MIN': 0.2756375269242213,
#  'defence_NE': 0.2772361407190506,
#  'defence_NO': 0.4732517404870511,
#  'defence_NYG': 0.317390689429861,
#  'defence_NYJ': 0.41732861226354734,
#  'defence_PHI': 0.6169827355805814,
#  'defence_PIT': 0.24556531285596875,
#  'defence_SEA': 0.39712126149204885,
#  'defence_SF': 0.24205223738014908,
#  'defence_TB': 0.1707473754840054,
#  'defence_TEN': 0.4148955590264643,
#  'defence_WAS': -0.008949098477570163,
#  'home_advantage': 2.6250054849812043e-14,
#  'rho': -0.1}

# %%
#Listado de Librerías instaladas
import subprocess

sub = subprocess.run(["pip", "list", '--disable-pip-version-check'],
                    stdout=subprocess.PIPE,
                    universal_newlines=True
                    )
pkgs = (line.rstrip().split() for line in sub.stdout.split("\n")[2: -1])

for paquete, version in pkgs:
    print(paquete, version)
# Out:
# absl-py 1.2.0
# aeppl 0.0.33
# aesara 2.7.9
# appdirs 1.4.4
# appnope 0.1.2
# argon2-cffi 21.3.0
# argon2-cffi-bindings 21.2.0
# arviz 0.12.1
# asttokens 2.0.5
# astunparse 1.6.3
# async-generator 1.10
# attrs 21.4.0
# backcall 0.2.0
# beautifulsoup4 4.11.1
# bidict 0.22.0
# bleach 4.1.0
# cachetools 5.2.0
# certifi 2022.6.15
# cffi 1.15.1
# cftime 1.6.1
# charset-normalizer 2.1.0
# cloudpickle 2.1.0
# configparser 5.3.0
# cons 0.4.5
# cramjam 2.5.0
# cssselect 1.1.0
# cycler 0.11.0
# debugpy 1.5.1
# decorator 5.1.1
# defusedxml 0.7.1
# deprecat 2.1.1
# dill 0.3.5.1
# empiricaldist 0.6.7
# entrypoints 0.4
# etuples 0.3.5
# executing 0.8.3
# facenet-pytorch 2.5.2
# fastjsonschema 2.15.1
# fastparquet 0.8.3
# fastprogress 1.0.3
# filelock 3.8.0
# flatbuffers 1.12
# fonttools 4.34.4
# fsspec 2022.8.2
# fxcmpy 1.3.3
# gast 0.4.0
# google-auth 2.10.0
# google-auth-oauthlib 0.4.6
# google-pasta 0.2.0
# graphviz 0.20.1
# grpcio 1.47.0
# h11 0.13.0
# h5py 3.7.0
# idna 3.3
# imageio 2.21.1
# importlib-metadata 4.12.0
# ipykernel 6.9.1
# ipython 8.4.0
# ipython-genutils 0.2.0
# jedi 0.18.1
# Jinja2 3.0.3
# joblib 1.1.0
# jsonschema 4.4.0
# jupyter-client 7.2.2
# jupyter-core 4.10.0
# jupyterlab-pygments 0.1.2
# keras 2.9.0
# Keras-Preprocessing 1.1.2
# kiwisolver 1.4.4
# lazy_loader 0.1rc2
# libclang 14.0.6
# littleutils 0.2.2
# logical-unification 0.4.5
# lxml 4.9.1
# Markdown 3.4.1
# MarkupSafe 2.1.1
# matplotlib 3.5.3
# matplotlib-inline 0.1.2
# mglearn 0.1.9
# miniKanren 1.0.3
# mistune 0.8.4
# multipledispatch 0.6.0
# nbclient 0.5.13
# nbconvert 6.4.4
# nbformat 5.3.0
# nest-asyncio 1.5.5
# netCDF4 1.6.0
# networkx 2.8.7
# nfl-data-py 0.3.0
# notebook 6.4.12
# numpy 1.23.2
# oauthlib 3.2.0
# opencv-python 4.6.0.66
# opt-einsum 3.3.0
# outcome 1.2.0
# outdated 0.2.1
# packaging 21.3
# pandas 1.4.3
# pandas-datareader 0.10.0
# pandas-flavor 0.3.0
# pandocfilters 1.5.0
# parso 0.8.3
# patsy 0.5.2
# penaltyblog 0.5.0
# pexpect 4.8.0
# pickleshare 0.7.5
# Pillow 9.2.0
# pingouin 0.5.2
# pip 22.1.2
# plotly 5.10.0
# prometheus-client 0.14.1
# prompt-toolkit 3.0.20
# protobuf 3.19.4
# ptyprocess 0.7.0
# PuLP 2.6.0
# pure-eval 0.2.2
# pyasn1 0.4.8
# pyasn1-modules 0.2.8
# pycparser 2.21
# Pygments 2.11.2
# pymc 4.1.4
# pymc3 3.11.5
# pyparsing 3.0.9
# pyrsistent 0.18.0
# PySocks 1.7.1
# python-dateutil 2.8.2
# python-dotenv 0.20.0
# python-engineio 4.3.1
# python-snappy 0.6.1
# python-socketio 5.0.4
# pytz 2022.2.1
# PyWavelets 1.4.1
# pyzmq 23.2.0
# requests 2.28.1
# requests-oauthlib 1.3.1
# rsa 4.9
# scikit-image 0.19.3
# scikit-learn 1.0.2
# scipy 1.9.0
# seaborn 0.11.2
# selenium 4.4.3
# semver 2.13.0
# Send2Trash 1.8.0
# setuptools 61.2.0
# sinfo 0.3.4
# six 1.16.0
# sniffio 1.2.0
# socketIO-client 0.7.2
# sortedcontainers 2.4.0
# soupsieve 2.3.1
# stack-data 0.2.0
# statsmodels 0.13.2
# stdlib-list 0.8.0
# tabulate 0.8.10
# tenacity 8.0.1
# tensorboard 2.9.1
# tensorboard-data-server 0.6.1
# tensorboard-plugin-wit 1.8.1
# tensorflow 2.9.1
# tensorflow-estimator 2.9.0
# tensorflow-io-gcs-filesystem 0.26.0
# termcolor 1.1.0
# terminado 0.13.1
# testpath 0.6.0
# Theano-PyMC 1.1.2
# threadpoolctl 3.1.0
# tifffile 2022.10.10
# toolz 0.12.0
# torch 1.12.1
# torchvision 0.13.1
# tornado 6.1
# tqdm 4.64.0
# traitlets 5.1.1
# trio 0.21.0
# trio-websocket 0.9.2
# typing_extensions 4.3.0
# urllib3 1.26.11
# wcwidth 0.2.5
# webdriver-manager 3.8.3
# webencodings 0.5.1
# websocket-client 1.4.1
# Werkzeug 2.2.2
# wheel 0.37.1
# wrapt 1.14.1
# wsproto 1.2.0
# xarray 2022.6.0
# xarray-einstats 0.3.0
# zipp 3.8.1
